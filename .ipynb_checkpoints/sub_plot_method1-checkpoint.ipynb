# %%
import matplotlib.pyplot as plt

x=[1,2,3,4,5]
y=[25,10,15,20,25]

plt.subplot(2,2,1)
plt.plot(x,y)
plt.title("Line Chart")

plt.subplot(2,2,2)
plt.bar(x,y)
plt.title("Bar Graph")

plt.subplot(2,2,3)
plt.scatter(x,y)
plt.title("Scatter plot")

plt.tight_layout()
