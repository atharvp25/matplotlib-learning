# %%
import matplotlib.pyplot as plt

x=[1,2,3,4,5]
y=[10,8,12,9,15]

plt.plot(x,y,marker="o")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.grid()
plt.savefig("save_fig.jpg",dpi=300,bbox_inches="tight")
